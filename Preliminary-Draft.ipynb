# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats 
import statsmodels.formula.api as smf

# %%
ls
# Out:
# API-Data_report.ipynb
# Analysis-Plan.ipynb
# Analysis-Report.ipynb
# Data-In-Hand.ipynb
# Final Project/
# Jepsen_Likes_Report.ipynb
# Jepsen_SystemsCheck.ipynb
# Preliminary-Draft.ipynb
# Sienna-ThanksgivingIG.csv
# Untitled.ipynb
# advertisers_using_your_activity_or_information.json
# api-requests_in-class_9_17.ipynb
# cces_example_data.csv
# dictionaires_inclass_9.3.ipynb
# in-class-10-1.ipynb
# in-class-10-24.ipynb
# in-class-11-14.ipynb
# in-class-9-24-24.ipynb
# in-class_8_27.ipynb
# in-class_9-3-24.ipynb
# inclass10-17.ipynb
# inclass9_10.ipynb
# keys.txt
# matplotlib10-15.ipynb
# spotfiy-api_in_class9-19.ipynb
# tidy_data_in_class.ipynb

# %%
tac = pd.read_csv('Sienna-ThanksgivingIG.csv', skiprows = 5)
tac.head()
# Out:
#      Query Id             Query Name                   Date  \
# 0  2002690947  Sienna-ThanksgivingIG  2024-11-22 20:37:09.0
# 1  2002690947  Sienna-ThanksgivingIG  2024-11-22 20:36:27.0
# 2  2002690947  Sienna-ThanksgivingIG  2024-11-22 20:35:23.0
# 3  2002690947  Sienna-ThanksgivingIG  2024-11-22 20:32:42.0
# 4  2002690947  Sienna-ThanksgivingIG  2024-11-22 20:30:31.0
#
#                                                Title  \
# 0  Thanksgiving cookie set #happythanksgivng #tha...
# 1  Peach cobbler cheesecake \n\n#peachcobbler #su...
# 2  This reel omg 🤣This cake is incredibly delicio...
# 3  🎉Let us do the baking for you this Thanksgivin...
# 4  With just 6️⃣ days left until Thanksgiving we ...
#
#                                              Snippet  \
# 0  Thanksgiving cookie set #happythanksgivng #tha...
# 1  Peach cobbler cheesecake #peachcobbler #suppor...
# 2  ...👉https://abarcascakes.com/product/fancy-pum...
# 3  ...#PeachCobblerPieInAJar #MadeFromScratch #Cu...
# ...

# %%
for i in tac.columns:
    print(i)
# Out:
# Query Id
# Query Name
# Date
# Title
# Snippet
# Url
# Domain
# Sentiment
# Page Type
# Language
# Country Code
# Continent Code
# Continent
# Country
# City Code
# Account Type
# Added
# Assignment
# Author
# Avatar
# Category Details
# Checked
# City
# Display URLs
# Engagement Score
# Entity Info
# Expanded URLs
# Facebook Author ID
# Facebook Comments
# Facebook Likes
# Facebook Role
# Facebook Shares
# Facebook Subtype
# Full Name
# Full Text
# Gender
# Hashtags
# Impact
# Impressions
# Instagram Comments
# Instagram Followers
# Instagram Following
# Instagram Interactions Count
# Instagram Likes
# Instagram Posts
# Interest
# Last Assignment Date
# Latitude
# Location Name
# Longitude
# Media Filter
# Media URLs
# Mentioned Authors
# Original Url
# Priority
# Professions
# Resource Id
# Short URLs
# Starred
# Status
# Subtype
# Tags
# Thread Author
# Thread Created Date
# Thread Entry Type
# Thread Id
# Thread URL
# Total Monthly Visitors
# X Author ID
# X Channel Role
# ...

# %%
tac[['Date', 'Title', 'Url', 'Author', 'Hashtags', 'Impressions', 'Instagram Likes', 'Instagram Comments', 'Instagram Interactions Count', 'Instagram Posts']]
# Out:
#                        Date  \
# 0     2024-11-22 20:37:09.0
# 1     2024-11-22 20:36:27.0
# 2     2024-11-22 20:35:23.0
# 3     2024-11-22 20:32:42.0
# 4     2024-11-22 20:30:31.0
# ...                     ...
# 2764  2024-11-20 23:50:10.0
# 2765  2024-11-20 22:52:51.0
# 2766  2024-11-20 21:54:05.0
# 2767  2024-11-20 21:52:10.0
# 2768  2024-11-20 20:51:50.0
#
#                                                   Title  \
# 0     Thanksgiving cookie set #happythanksgivng #tha...
# 1     Peach cobbler cheesecake \n\n#peachcobbler #su...
# 2     This reel omg 🤣This cake is incredibly delicio...
# 3     🎉Let us do the baking for you this Thanksgivin...
# 4     With just 6️⃣ days left until Thanksgiving we ...
# ...                                                 ...
# 2764  picy-Sweet Cranberry Salsa with Fresh Cilantro...
# 2765  Tis the season 🧡\n\n#localbaker #wakullacounty...
# 2766  Happy Halloween, friends!👻🎃 Who is dressing up...
# ...

# %%
tac.groupby('Title').count().\
sort_values('Instagram Likes', ascending = False)
# Out:
#                                                     Query Id  Query Name  \
# Title
# Looking for festive baking inspiration? Our Chr...        47          47
# Serve up a slice of holiday happiness! 🥧✨ This ...        11          11
# 🎄✨ Holiday Baking Essentials at Unbeatable Pric...         6           6
# Christmas Edition 2024 by Noir Bakehouse \n\nWe...         3           3
# Swing by an Essig Family McDonald's today and p...         3           3
# ...                                                      ...         ...
# #mrsbrownskitchen #christmasbaking #fivestarbar...         1           1
# #mrsbrownskitchen #christmasbaking #oreocheesecake         1           1
# #palmbeachfarmersmarket #hotamarkets #evergreen...         1           1
# #pieschool everyday until Thanksgiving! Today, ...         1           1
# ‼️🍂🐾 Limited Edition Treats for Your Pup This S...         1           1
#
#                                                     Date  Snippet  Url  \
# Title
# ...

# %%
tac.head(25)
# Out:
#       Query Id             Query Name                   Date  \
# 0   2002690947  Sienna-ThanksgivingIG  2024-11-22 20:37:09.0
# 1   2002690947  Sienna-ThanksgivingIG  2024-11-22 20:36:27.0
# 2   2002690947  Sienna-ThanksgivingIG  2024-11-22 20:35:23.0
# 3   2002690947  Sienna-ThanksgivingIG  2024-11-22 20:32:42.0
# 4   2002690947  Sienna-ThanksgivingIG  2024-11-22 20:30:31.0
# 5   2002690947  Sienna-ThanksgivingIG  2024-11-22 20:30:00.0
# 6   2002690947  Sienna-ThanksgivingIG  2024-11-22 20:28:53.0
# 7   2002690947  Sienna-ThanksgivingIG  2024-11-22 20:28:06.0
# 8   2002690947  Sienna-ThanksgivingIG  2024-11-22 20:27:59.0
# 9   2002690947  Sienna-ThanksgivingIG  2024-11-22 20:27:32.0
# 10  2002690947  Sienna-ThanksgivingIG  2024-11-22 20:27:27.0
# 11  2002690947  Sienna-ThanksgivingIG  2024-11-22 20:26:29.0
# 12  2002690947  Sienna-ThanksgivingIG  2024-11-22 20:25:18.0
# 13  2002690947  Sienna-ThanksgivingIG  2024-11-22 20:25:08.0
# ...

# %%
tac.drop(columns = ['[Wizard-1] Content Types - Images', '[Wizard-1] Content Types - Videos',\
                    '[Wizard-1] Hashtag:coronavirus - coronavirus','[Wizard-2] Content Types - Images',\
        '[Wizard-2] Content Types - Videos', '[Wizard-3] Content Types - Images', '[Wizard-3] Content Types - Videos'])
# Out:
#         Query Id             Query Name                   Date  \
# 0     2002690947  Sienna-ThanksgivingIG  2024-11-22 20:37:09.0
# 1     2002690947  Sienna-ThanksgivingIG  2024-11-22 20:36:27.0
# 2     2002690947  Sienna-ThanksgivingIG  2024-11-22 20:35:23.0
# 3     2002690947  Sienna-ThanksgivingIG  2024-11-22 20:32:42.0
# 4     2002690947  Sienna-ThanksgivingIG  2024-11-22 20:30:31.0
# ...          ...                    ...                    ...
# 2764  2002690947  Sienna-ThanksgivingIG  2024-11-20 23:50:10.0
# 2765  2002690947  Sienna-ThanksgivingIG  2024-11-20 22:52:51.0
# 2766  2002690947  Sienna-ThanksgivingIG  2024-11-20 21:54:05.0
# 2767  2002690947  Sienna-ThanksgivingIG  2024-11-20 21:52:10.0
# 2768  2002690947  Sienna-ThanksgivingIG  2024-11-20 20:51:50.0
#
#                                                   Title  \
# 0     Thanksgiving cookie set #happythanksgivng #tha...
# 1     Peach cobbler cheesecake \n\n#peachcobbler #su...
# ...

# %%
tac.columns
# Out:
# Index(['Query Id', 'Query Name', 'Date', 'Title', 'Snippet', 'Url', 'Domain',
#        'Sentiment', 'Page Type', 'Language',
#        ...
#        'Tiktok Shares', 'Weblog Title', '[Wizard-1] Content Types - Images',
#        '[Wizard-1] Content Types - Videos',
#        '[Wizard-1] Hashtag:coronavirus - coronavirus',
#        '[Wizard-2] Content Types - Images',
#        '[Wizard-2] Content Types - Videos',
#        '[Wizard-3] Content Types - Images',
#        '[Wizard-3] Content Types - Videos', 'Emotion'],
#       dtype='object', length=155)

# %%
fig1, ax1 = plt.subplots() 
ax1.hist(tac['Title'])
plt.show()

# %% [markdown]
# #### Since loading in the data was unsuccessful, I looked through the Excel sheet and noticed a few different things. The data is only from the past week, which will be helpful because it has only started to really ramp up with holiday recipes recently, now that it is November. I was given 2500 mentions which is more than plenty for this assignment, but I know that it will allow me to have a variety of hashtags to work with and weed out the ones I don't need. I gave a list of hashtags that could result in many different desserts, so I'm sure that some of them won't apply in the way I need but I'll have extra variables. This data is also from Brandwatch, gathered only from Instagram with the hashtags I wanted. Some posts have a lot of interactions and that could mean they are very popular posts, and some have none. I'm interested to know more about the helpful data once it is loaded and tidied.

# %% [markdown]
# #### For my analysis plan, I want to create a few dataframes that will help me narrow down and analyze the hashtags that I have from BrandWatch. This will hopefully help me see some of the reoccurring trends and make a few assumptions based on the data. This is where I will choose about 10 or so hashtags that have garnered the most attention and analyze how they are being used. I think that using the posts with the highest number of engagements will show me the best results. According to BrandWatch's website, they describe engagements as the number of new reactions, comments, and shares during the one week period that this data was gathered from. I plan to break those 3 points down even further because this seems to be what I am most interested in knowing about for these posts. I will use histograms and scatterplots to visualize the data and see how they compare to each other. I also think that it will be interesting to compare the differences between engagements of videos versus photos and see which one performs better or has the best interactions. Personally, I interact with videos more than photos when it comes to baking posts on Instagram so I will be curious to see if other people feel the same as I do. I still was not able to load in this data and cannot seem to figure out why but once that problem is fixed, hopefully the enxt few steps will go much more smoothly.

# %% [markdown]
# #### I have recently found a love for baking and I try to incorporate it into my daily life. I usually find recipes that I want to try out from Instagram or Tiktok. Because of this, I was interested in seeing how a social media platform like Instagram uses hashtags that are popular and trending during the holiday seasons for baking. From what I've seen in my own social media consumption recently, there are particular desserts that have been trending this year and I am curious to see if that is reflected in the data that has been collected from November 16th to November 23rd, 2024.

# %% [markdown]
# #### I wanted to look at data related to baking, so my first thought went to social media. Instagram is where I find and see a lot of recipes that I save and follow along with, so my data was gathered from this app using Brandwatch. I would have also liked to look into TikTok also, but Instagram has enough content that it would get overwhelming to use both apps.

# %% [markdown]
# #### The data that I am using for this project comes from Instagram and is gathered by Brandwatch. Brandwatch is a social media analytics and listening tool that has taken data from Instagram with specific hashtags I have requested and pulled 2500 posts and videos that are related. They are a very reliable source to get data from so I know that the information will be accurate and help me with this final project.

# %% [markdown]
# #### Explain the structure of the data (how is it organized, what pieces of information are included, which pieces will you use?) (these last two are the data ethnographies portions)
# #### The data is organized into the most important categories taken from Instagram. I included date, author, hashtags, impressions, and some of the other Instagram-specific data that wers taken by Brandwatch. I need to continue and

# %% [markdown]
# #### I definitely have some confusion about how to proceed and finalize most of this data. As I've stated above, I want to tidy the data down to understand more about the trending desserts on Instagram, but I seem to have only made the "tidied" data larger? I think that I am struggling to find the correct method of tidying the data to get exactly what I want, and that is what I plan to figure out before the due date.

# %% [markdown]
# #### Once everything is sorted properly, I hope that the audience can see the trends of desserts over the holidays and how it has fluctuated because of different factors. When I can execute the graphs, the visualization of a scatter plot or histogram will show where the trends lie, if there are obvious ones or not.
